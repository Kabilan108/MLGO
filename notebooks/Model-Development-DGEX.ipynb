# %%
# Folder setup
from google.colab import drive
drive.mount('/content/drive')
# !ln -s "/content/drive/My Drive/MLGO" "/content/MLGO"

import os
os.chdir("/content/MLGO")
# Out:
# Mounted at /content/drive

# %%
# Git setup
username = "Kabiilan108"
repo = "MLGO"
token = "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"

# !git config --global core.fileMode false
# !git config --global user.email "you@example.com"
# !git config --global user.name "Your Name"

# %%
# !git commit notebooks/Model-Development-DGEX.ipynb -m 'Add notebook for training D-GEX'
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@8daf03c3ecd8.(none)')

# %% [markdown]
# # Model Development
# ## D-GEX
#
# In this notebook, I will evaluate the performance of theoriginal D-GEX model in predicting Gene Ontology terms.
